# %%
import numpy as np
from wigner import Su2Group

# %%
dim: int = 4

# %%
Su2Group(dim).kernel
# Out:
# Matrix([
# [                      3*sqrt(35)*cos(theta)/160 + 3*sqrt(15)*cos(theta)/20 + 3*sqrt(5)*cos(2*theta)/16 + sqrt(35)*cos(3*theta)/32 + sqrt(5)/16 + 1/4, sqrt(105)*exp(-I*phi)*sin(theta)/160 + 3*sqrt(5)*exp(-I*phi)*sin(theta)/20 + sqrt(15)*exp(-I*phi)*sin(2*theta)/8 + sqrt(105)*exp(-I*phi)*sin(3*theta)/32, sqrt(105)*exp(-2*I*phi)*cos(theta)/32 - sqrt(15)*exp(-2*I*phi)*cos(2*theta)/16 - sqrt(105)*exp(-2*I*phi)*cos(3*theta)/32 + sqrt(15)*exp(-2*I*phi)/16,                                                                          3*sqrt(35)*exp(-3*I*phi)*sin(theta)/32 - sqrt(35)*exp(-3*I*phi)*sin(3*theta)/32],
# ...

# %%
Su2Group(dim).wigner_transform_expr
# Out:
# (sqrt(15)*re(o_0_2)/8 + sqrt(15)*re(o_1_3)/8)*cos(2*phi) + (sqrt(15)*im(o_0_2)/8 + sqrt(15)*im(o_1_3)/8)*sin(2*phi) + ((sqrt(15)*re(o_0_1)/4 - sqrt(15)*re(o_2_3)/4)*cos(phi) + (sqrt(15)*im(o_0_1)/4 - sqrt(15)*im(o_2_3)/4)*sin(phi))*sin(2*theta) + ((-sqrt(105)*re(o_0_2)/16 + sqrt(105)*re(o_1_3)/16)*cos(2*phi) + (-sqrt(105)*im(o_0_2)/16 + sqrt(105)*im(o_1_3)/16)*sin(2*phi) + sqrt(35)*(re(o_0_0) - 3*re(o_1_1) + 3*re(o_2_2) - re(o_3_3))/32)*cos(3*theta) + ((-sqrt(15)*re(o_0_2)/8 - sqrt(15)*re(o_1_3)/8)*cos(2*phi) + (-sqrt(15)*im(o_0_2)/8 - sqrt(15)*im(o_1_3)/8)*sin(2*phi) + 3*sqrt(5)*(re(o_0_0) - re(o_1_1) - re(o_2_2) + re(o_3_3))/16)*cos(2*theta) + ((sqrt(105)*re(o_0_1)/16 - 3*sqrt(35)*re(o_1_2)/16 + sqrt(105)*re(o_2_3)/16)*cos(phi) + (sqrt(105)*im(o_0_1)/16 - 3*sqrt(35)*im(o_1_2)/16 + sqrt(105)*im(o_2_3)/16)*sin(phi) - sqrt(35)*sin(3*phi)*im(o_0_3)/16 - sqrt(35)*cos(3*phi)*re(o_0_3)/16)*sin(3*theta) + ((sqrt(105)*re(o_0_1)/80 + 3*sqrt(5)*re(o_0_1)/10 - 3*sqrt(35)*re(o_1_2)/80 + sqrt(15
# ...

# %%
Su2Group(dim).wigner_transform(0, 0, np.eye(dim))
print(Su2Group(dim)._wg_transform.__doc__)
# Out:
# Created with lambdify. Signature:
#
# func(theta, phi, o_0_0, o_0_1, o_0_2, o_0_3, o_1_1, o_1_2, o_1_3,
#         o_2_2, o_2_3, o_3_3)
#
# Expression:
#
# (sqrt(15)*re(o_0_2)/8 + sqrt(15)*re(o_1_3)/8)*cos(2*phi) +...
#
# Source code:
#
# def _lambdifygenerated(theta, phi, o_0_0, o_0_1, o_0_2, o_0_3, o_1_1, o_1_2, o_1_3, o_2_2, o_2_3, o_3_3):
#     x0 = real(o_0_0)
#     x1 = real(o_1_1)
#     x2 = real(o_2_2)
#     x3 = real(o_3_3)
#     x4 = sqrt(5)
#     x5 = (1/16)*x4
#     x6 = 2*phi
#     x7 = cos(x6)
#     x8 = real(o_0_2)
#     x9 = sqrt(15)
#     x10 = (1/8)*x9
#     x11 = real(o_1_3)
#     x12 = x10*x11 + x10*x8
#     x13 = sin(x6)
#     x14 = imag(o_0_2)
#     x15 = imag(o_1_3)
#     x16 = x10*x14 + x10*x15
#     x17 = 2*theta
#     x18 = cos(phi)
#     x19 = real(o_0_1)
#     x20 = (1/4)*x9
#     x21 = real(o_2_3)
#     x22 = sin(phi)
#     x23 = imag(o_0_1)
#     x24 = imag(o_2_3)
#     x25 = 3*theta
#     x26 = sqrt(35)
#     x27 = sqrt(105)
#     x28 = (1/16)*x27
# ...
